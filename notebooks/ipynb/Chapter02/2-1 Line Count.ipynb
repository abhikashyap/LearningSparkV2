# %%
import sys
from io import StringIO

old_stderr = sys.stderr
sys.stderr = StringIO()

from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("LearningSparkV2") \
    .master("local[*]") \
    .config("spark.driver.extraJavaOptions", 
            "-Dlog4j.configurationFile=file:///Users/abhikashyap10/spark/LearningSparkV2/log4j2.properties") \
    .getOrCreate()

spark.sparkContext.setLogLevel("ERROR")
print(f"Spark {spark.version} ready")

sys.stderr = old_stderr
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Spark 4.1.1 ready

# %% [markdown]
# ## Example 2-1 Line Count

# %%
spark.version
# Out:
# '4.1.1'

# %%
strings = spark.read.text("/Users/abhikashyap10/spark/LearningSparkV2/databricks-datasets/learning-spark-v2/SPARK_README.md")
strings.show(10, truncate=False)
# Out:
# +------------------------------------------------------------------------------+
# |value                                                                         |
# +------------------------------------------------------------------------------+
# |# Apache Spark                                                                |
# |                                                                              |
# |Spark is a fast and general cluster computing system for Big Data. It provides|
# |high-level APIs in Scala, Java, Python, and R, and an optimized engine that   |
# |supports general computation graphs for data analysis. It also supports a     |
# |rich set of higher-level tools including Spark SQL for SQL and DataFrames,    |
# |MLlib for machine learning, GraphX for graph processing,                      |
# |and Spark Streaming for stream processing.                                    |
# |                                                                              |
# ...

# %%
strings.count()
# Out:
# 95

# %%
filtered = strings.filter(strings.value.contains("Spark"))
filtered.count()
# Out:
# 17
